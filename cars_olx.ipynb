# %% [markdown]
# scrabing all car selling advertisments made by a single user in olx

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup as bs
import requests

# %%
url1='car-for-sale-ID6PS6E.html'
url2='for-sale-ID6PJ87.html'
url3='car-for-sale-ID6PLR5.html'
url4='car-for-sale-ID6PIok.html'
url5='sale-car-ID6PIjj.html'
urls=[url1,url2,url3,url4,url5]
olx_cars_url='https://olx.qa/en/ad/'
r1=requests.get(olx_cars_url+url1)
r2=requests.get(olx_cars_url+url2)    
r3=requests.get(olx_cars_url+url3)
r4=requests.get(olx_cars_url+url4)

# %%
soup1=bs(r1.content)
soup2=bs(r2.content)
soup3=bs(r3.content)
soup4=bs(r4.content)

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="z6Q-K-N50k0RiFlZrubcvo6azvQ5VU3QPeqlG7n3Thw" name="google-site-verification"/>
#   <meta content="5A57304F35F5718EAD39F1A8E1EE8D3C" name="msvalidate.01"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Car for sale Ar Rayyan - OLX Qatar
#   </title>
#   <meta content="index, follow" name="robots"/>
#   <link href="https://olx.qa/ad/car-for-sale-ID6PS6E.html" rel="canonical"/>
#   <link href="https://olx.qa/ad/car-for-sale-ID6PS6E.html" hreflang="ar" rel="alternate"/>
#   <link href="https://olx.qa/en/ad/car-for-sale-ID6PS6E.html" hreflang="en" rel="alternate"/>
#   <link href="https://olx.qa/i2/ad/car-for-sale-ID6PS6E.html" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <meta content="en" http-equiv="Content-Language"/>
#   <meta content="290 QAR: For sale
# ...

# %%
car_des1=soup1.find("meta",  property="twitter:description")
title=soup1.find("meta",  property="twitter:title")
print(title["content"] if title else "No meta title given")
print(car_des1["content"] if car_des else "No meta url given")
# Out:
# Car for sale Ar Rayyan - OLX Qatar
# 290 QAR: For sale
# Range Rover sport SVR. Black color inside black leather.
# Model : 2017
# Mileage : 38.000 km
# Price : 290.000 Qr

# %%
car_des2=soup2.find("meta",  property="twitter:description")
title=soup2.find("meta",  property="twitter:title")
print(title["content"] if title else "No meta title given")
print(car_des2["content"] if car_des else "No meta url given")
# Out:
# For sale Ar Rayyan - OLX Qatar
# 57 QAR: For sale
# Nissan patrol Super Safari. White color inside clothes beige.
# Model : 2005
# Mileage : 317.000 km
# Price ; : 57. 000 Qr

# %%
car_des3=soup3.find("meta",  property="twitter:description")
title=soup3.find("meta",  property="twitter:title")
print(title["content"] if title else "No meta title given")
print(car_des3["content"] if car_des else "No meta url given")
# Out:
# Car for sale Ar Rayyan - OLX Qatar
# 100 QAR: For sale
# Ford Raptor V8 color beige inside black clothes
# Model : 2014
# Mileage : 213.000 km
# Price : 100.000 Qr

# %%
car_des4=soup4.find("meta",  property="twitter:description")
title=soup4.find("meta",  property="twitter:title")
print(title["content"] if title else "No meta title given")
print(car_des4["content"] if car_des else "No meta url given")
# Out:
# Car for sale Ar Rayyan - OLX Qatar
# 35 QAR: For sale
# Toyota Camry GL white color inside beige clothes.
# Model : 2016
# Mileage : 420.000 km
# Price : 35. 000 Qr

# %%
cars=[]

# %%
cars.append(car_des1['content'])
cars.append(car_des2['content'])
cars.append(car_des3['content'])
cars.append(car_des4['content'])

# %%
cars
# Out:
# ['290 QAR: For sale\nRange Rover sport SVR. Black color inside black leather.\nModel : 2017\nMileage : 38.000 km\nPrice : 290.000 Qr',
#  '57 QAR: For sale\nNissan patrol Super Safari. White color inside clothes beige.\nModel : 2005\nMileage : 317.000 km\nPrice ; : 57. 000 Qr',
#  '100 QAR: For sale\nFord Raptor V8 color beige inside black clothes\nModel : 2014\nMileage : 213.000 km\nPrice : 100.000 Qr',
#  '35 QAR: For sale\nToyota Camry GL white color inside beige clothes.\nModel : 2016\nMileage : 420.000 km\nPrice : 35. 000 Qr']

# %%
car_name=[]
car_describtion=[]
model=[]
mileage=[]
price=[]

# %%
def get_data():
    for j,value in enumerate(car_data):
        if j==0:
            continue
        elif j==1:
            car_name.append(value)
            
        elif j==2:
            model.append(value.split(':')[1])
            
        elif j==3:
            mileage.append(value.split(':')[1])
        elif j==4:
            price.append(value.split(':')[1])

# %%
for j,car in enumerate(cars):
    car_data=cars[j].split('\n')
    get_data()

# %%
car_name
# Out:
# ['Range Rover sport SVR. Black color inside black leather.',
#  'Nissan patrol Super Safari. White color inside clothes beige.',
#  'Ford Raptor V8 color beige inside black clothes',
#  'Toyota Camry GL white color inside beige clothes.']

# %%
model
# Out:
# [' 2017', ' 2005', ' 2014', ' 2016']

# %%
mileage
# Out:
# [' 38.000 km', ' 317.000 km', ' 213.000 km', ' 420.000 km']

# %%
price
# Out:
# [' 290.000 Qr', ' 57. 000 Qr', ' 100.000 Qr', ' 35. 000 Qr']

# %%
l=[]
columns=['car_describition','model','mileage','price']
cars_sale=pd.DataFrame(l,columns=columns)

# %%
cars_sale.head()
# Out:
# Empty DataFrame
# Columns: [car_describition, model, mileage, price]
# Index: []

# %%
cars_sale['car_describition']=car_name
cars_sale['model']=model
cars_sale['mileage']=mileage
cars_sale['price']=price

# %%
cars_sale.head()
# Out:
#                                     car_describition  model      mileage  \
# 0  Range Rover sport SVR. Black color inside blac...   2017    38.000 km
# 1  Nissan patrol Super Safari. White color inside...   2005   317.000 km
# 2    Ford Raptor V8 color beige inside black clothes   2014   213.000 km
# 3  Toyota Camry GL white color inside beige clothes.   2016   420.000 km
#
#          price
# 0   290.000 Qr
# 1   57. 000 Qr
# 2   100.000 Qr
# 3   35. 000 Qr
